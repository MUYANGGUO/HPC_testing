# %% [markdown]
# # Timings

# %% [markdown]
# This assignment is meant to be run on **four nodes** with 28 cores.
#
# One thing we are trying to do is gauge the performance of a good MPI implementation and compare it to a good OpenMP implementation.  In order to do this, we will have to load some slightly different modules.

# %%
# %%bash
# module unload cse6230
# module load cse6230/gcc-omp-gpu
# module list
# Out:
#  =========================================================================
# |                                                                         |
# |       A note about python/3.6:                                          |
# |       PACE is lacking the staff to install all of the python 3          |
# |       modules, but we do maintain an anaconda distribution for          |
# |       both python 2 and python 3. As conda significantly reduces        |
# |       the overhead with package management, we would much prefer        |
# |       to maintain python 3 through anaconda.                            |
# |                                                                         |
# |       All pace installed modules are visible via the module avail       |
# |       command.                                                          |
# |                                                                         |
#  =========================================================================
# Currently Loaded Modulefiles:
#   1) curl/7.42.1
#   2) git/2.13.4
#   3) python/3.6
#   4) /nv/coc-ice/tisaac3/opt/pace-ice/modulefiles/jupyter/1.0
#   5) cuda/9.1
#   6) /nv/coc-ice/tisaac3/opt/pace-ice/modulefiles/gcc/9.2.0-offload
#   7) /nv/coc-ice/tisaac3/opt/pace-ice/modulefiles/hpctoolkit/2018.18-gcc
#   8) hwloc/1.10.0(default)
#   9) /nv/coc-ice/tisaac3/opt/pace-ice/modulefiles/mvapich2/2.3-gcc
#  10) cse6230/gcc-omp-gpu

# %% [markdown]
# ([mvapich](http://mvapich.cse.ohio-state.edu/) is a fork of the [mpich](https://www.mpich.org/) MPI implementation with some modifications for performance on various HPC hardware)

# %% [markdown]
# ## Measuring MPI primitives
#
# **Task 1 (3 pts)** The file `benchmarks.c` includes some basic benchmarks for measuring the performance of various MPI point-to-point and collective operations.  Right now, it is incomplete!

# %%
# !grep "TODO" benchmarks.c
# Out:
#   /* TODO: split the communicator `comm` into one communicator for ranks
#   /* TODO: destroy the subcommunicator created in `splitCommunicator` */
#   /* TODO: Record the MPI walltime in `tic_p` */
#   /* TODO: Get the elapsed MPI walltime since `tic_in`,
#   /* TODO: take the times from all processes and compute the maximum,
#       /* TODO: ??? MPI_REPLACE?
#       /* TODO: Set up a ping pong test for the scatter collective.  When
#       /* TODO: Set up a timing loop for the following:
#       /* TODO: Set up a timing loop for the following:
#       /* TODO: Set up a timing loop for the following:

# %% [markdown]
# Refering to a good [MPI Tutorial](https://computing.llnl.gov/tutorials/mpi/) or
# [lecture notes](http://vuduc.org/cse6230/slides/cse6230-fa14--06-mpi.pdf) as needed,
# fill in the missing MPI routines.
#
# Once you have done that, run the following script to generate a graph of benchmark bandwidths of MPI routines.  Note that these values are only for MPI messages within a node: values may be different when we start using multiple nodes.

# %%
# !make runbenchmarks
# Out:
# mpirun -f /var/spool/torque/aux//109458.ice-sched.pace.gatech.edu -n 28 ./benchmarks
# MPI Version: 3.0
# Intel(R) MPI Library 5.1.1 for Linux* OS
#
# MPI # Procs: 28
# MPI Wtime 1.57112e+09, precision 1e-06
# MPI Wtime is global
# MPI proc 0 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 1 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 2 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 3 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 4 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 5 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 6 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 7 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 8 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 9 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 10 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 11 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 12 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 13 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 14 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 15 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 16 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 17 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 18 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 19 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 20 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 21 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 22 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 23 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 24 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 25 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 26 host: rich133-h35-17-r.pace.gatech.edu
# MPI proc 27 host: rich133-h35-17-r.pace.gatech.edu
# MPI Point-to-point ping-pong test:
#  # Processes  | Message Size | Total Size   | Time         | B/s
#            14              8            112   +6.62804e-07   +1.68979e+08
#            14             64            896   +8.21829e-07   +1.09025e+09
#            14            512           7168   +1.05190e-06   +6.81432e+09
#            14           4096          57344   +2.34199e-06   +2.44852e+10
#            14          32768         458752   +1.16949e-05   +3.92266e+10
#            14         262144        3670016   +6.72879e-05   +5.45420e+10
#            14        2097152       29360128   +5.09117e-04   +5.76687e+10
#            28              8            224   +1.57189e-06   +1.42503e+08
#            28             64           1792   +3.19815e-06   +5.60324e+08
#            28            512          14336   +2.52199e-06   +5.68440e+09
#            28           4096         114688   +6.97303e-06   +1.64474e+10
#            28          32768         917504   +4.51829e-05   +2.03064e+10
#            28         262144        7340032   +3.08374e-04   +2.38024e+10
#            28        2097152       58720256   +4.67241e-03   +1.25675e+10
# MPI Broadcast ping-pong test:
#  # Processes  | Message Size | Total Size   | Time         | B/s
#            14              8            208   +7.51019e-07   +2.76957e+08
#            14             64           1664   +7.92027e-07   +2.10094e+09
#            14            512          13312   +1.04380e-06   +1.27534e+10
#            14           4096         106496   +2.43998e-06   +4.36463e+10
#            14          32768         851968   +1.17409e-05   +7.25640e+10
#            14         262144        6815744   +1.12000e-04   +6.08549e+10
#            14        2097152       54525952   +8.07175e-04   +6.75516e+10
#            28              8            432   +1.14799e-06   +3.76311e+08
#            28             64           3456   +1.07408e-06   +3.21765e+09
#            28            512          27648   +1.59907e-06   +1.72900e+10
#            28           4096         221184   +3.44110e-06   +6.42772e+10
#            28          32768        1769472   +2.07551e-05   +8.52550e+10
#            28         262144       14155776   +1.64802e-04   +8.58956e+10
#            28        2097152      113246208   +1.04128e-03   +1.08757e+11
# MPI Scatter ping-pong test:
#  # Processes  | Message Size | Total Size   | Time         | B/s
#            14              8            208   +2.57111e-06   +8.08990e+07
#            14             64           1664   +3.14713e-06   +5.28737e+08
#            14            512          13312   +4.96411e-06   +2.68165e+09
#            14           4096         106496   +1.84932e-05   +5.75866e+09
#            14          32768         851968   +1.00832e-04   +8.44936e+09
#            28              8            432   +4.60601e-06   +9.37905e+07
#            28             64           3456   +5.90801e-06   +5.84968e+08
#            28            512          27648   +1.14870e-05   +2.40689e+09
#            28           4096         221184   +5.97491e-05   +3.70188e+09
#            28          32768        1769472   +2.90277e-04   +6.09580e+09
# MPI All-reduce test:
#  # Processes  | Message Size | Total Size   | Time         | B/s
#            14              8            208   +2.18892e-06   +9.50240e+07
#            14             64           1664   +2.51889e-06   +6.60608e+08
#            14            512          13312   +3.21412e-06   +4.14172e+09
#            14           4096         106496   +7.84516e-06   +1.35747e+10
#            14          32768         851968   +2.98772e-05   +2.85157e+10
#            14         262144        6815744   +2.30040e-04   +2.96285e+10
#            14        2097152       54525952   +2.47462e-03   +2.20341e+10
#            28              8            432   +3.70789e-06   +1.16508e+08
#            28             64           3456   +4.08602e-06   +8.45811e+08
#            28            512          27648   +5.67508e-06   +4.87183e+09
#            28           4096         221184   +1.34840e-05   +1.64034e+10
#            28          32768        1769472   +9.89902e-05   +1.78752e+10
#            28         262144       14155776   +3.16543e-04   +4.47199e+10
#            28        2097152      113246208   +3.02285e-03   +3.74634e+10
# MPI All-gather test:
#  # Processes  | Message Size | Total Size   | Time         | B/s
#            14              8           1456   +1.92499e-06   +7.56367e+08
#            14             64          11648   +2.28214e-06   +5.10398e+09
#            14            512          93184   +3.82209e-06   +2.43804e+10
#            14           4096         745472   +1.51949e-05   +4.90607e+10
#            14          32768        5963776   +1.12788e-04   +5.28760e+10
#            28              8           6048   +4.02308e-06   +1.50333e+09
#            28             64          48384   +5.14507e-06   +9.40395e+09
#            28            512         387072   +1.64270e-05   +2.35631e+10
#            28           4096        3096576   +5.95028e-05   +5.20408e+10
#            28          32768       24772608   +3.00674e-04   +8.23902e+10
# MPI All-to-all test:
#  # Processes  | Message Size | Total Size   | Time         | B/s
#            14              8           1352   +6.48499e-06   +2.08482e+08
#            14             64          10816   +7.26199e-06   +1.48940e+09
#            14            512          86528   +9.67717e-06   +8.94146e+09
#            14           4096         692224   +2.09179e-05   +3.30924e+10
#            14          32768        5537792   +1.21054e-04   +4.57464e+10
#            28              8           5832   +2.60150e-05   +2.24178e+08
#            28             64          46656   +2.89361e-05   +1.61238e+09
#            28            512         373248   +3.93431e-05   +9.48700e+09
#            28           4096        2985984   +1.03069e-04   +2.89707e+10
#            28          32768       23887872   +7.36798e-04   +3.24212e+10

# %%
from IPython.display import Image
Image(filename='benchmarks.png')

# %% [markdown]
# (Right now the graph is showing no values because the "timing" values are negative until you complete the code)

# %% [markdown]
# **Task 2 (2 pts)** We've talked in class about a simplified model of the cost of an MPI message: $\lambda + g b$, where $\lambda$ is the latency and $g$ is the inverse bandwidth.
# Using your graph for Send/Recv bandwidths for different message sizes (which was simply calculated from dividing the message size by the message time), estimate $\lambda$ (units secs) and $g$ (units secs/byte) for this MPI implementation on these nodes.

# %% [markdown]
# **Task 4 (3 pts)** The point-to-point sends and receives in MPI are _symmetric_: there must be a receive for each send.  What if we start with a list of messages that is _asymmetric_: we know who to send to, but not who to receive from.
#
# Suppose rank $i$ has $N_i$ messages bound for receivers $r_{i,j}$ for $1 \leq j \leq N_i$.  Let $S_{i,j}$ be the size of the message from $i$ to $r_{i,j}$, and let $S_i = \sum_j S_{i,j}$ be the total outgoing message volume from rank $i$.
#
# Process $r_{i,j}$ does not know it is going to receive a message from $i$.
#
# Give pseudocode below for two algorithms, using MPI sends, receives, and collectives that we have talked about, to send all of the messages.
#
# In the first one, assume that there is a large volume of communication: that $S_i \in O(P)$ for each $i$.
#
# In the second one, assume that there is a small volume of communication, and a small number of communicators:
# $S_i \in O(1)$, and each rank needs to send or receive a message from $O(1)$ other processes.
